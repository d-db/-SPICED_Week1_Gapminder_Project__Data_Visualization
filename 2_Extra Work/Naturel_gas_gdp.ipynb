# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import imageio

import seaborn as sns

# %%
gas = pd.read_csv("./data/natural_gas_production_total.csv", index_col=0)

# %%
gas
# Out:
#                        1970   1971   1972   1973   1974   1975   1976   1977  \
# country
# United Arab Emirates   698k  1.23M  1.25M  1.45M  1.46M  1.39M  1.63M  3.27M
# Argentina             5.03M  5.44M  5.17M  5.63M  6.06M  6.43M  6.13M  6.33M
# Australia             1.49M  2.22M  3.19M  4.05M  4.62M  4.96M  5.85M  6.69M
# Azerbaijan              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bangladesh                0      0   378k   523k   575k   578k   761k   849k
# Bahrain                559k   815k  1.02M  1.44M  1.78M  1.87M  1.96M  2.13M
# Bolivia                 36k    36k   960k  1.48M  1.55M  1.53M  1.57M  1.66M
# Brazil                69.7k   111k   151k   173k   332k   362k   417k   519k
# Brunei                 184k   182k   373k  1.63M  3.54M  4.64M  6.12M  7.03M
# Canada                46.4M  50.8M  57.3M  61.4M  60.2M  61.4M    62M  65.1M
# China                 2.49M  3.24M  4.19M  5.18M  6.53M  7.67M  8.75M  10.5M
# ...

# %%
gas_agg = gas.loc[["Norway", "Saudi Arabia"], :"2005"]

# %%
gas_agg
# Out:
#                1970  1971   1972   1973   1974   1975   1976   1977   1978  \
# country
# Norway            0     0      0      0      0      0      0  2.27M  12.1M
# Saudi Arabia  1.32M  1.1M  1.25M  1.47M  1.86M  2.21M  2.39M  3.36M  4.64M
#
#                1979  ...   1996   1997   1998   1999   2000   2001   2002  \
# country              ...
# Norway        17.6M  ...  31.9M  36.6M  37.7M  41.4M  42.5M  46.1M    56M
# Saudi Arabia  5.69M  ...  36.3M    37M  38.2M  37.7M  40.7M  43.9M  46.3M
#
#                2003   2004   2005
# country
# Norway        62.3M  67.6M  73.3M
# Saudi Arabia  49.1M  53.7M  58.2M
#
# [2 rows x 36 columns]

# %%
gas_norway = gas_norway.melt(id_vars='country', var_name='year', value_name='gas_production')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 gas_norway = gas_norway.melt(id_vars='country', var_name='year', value_name='gas_production')
#
# NameError: name 'gas_norway' is not defined

# %%
gas_norway

# %% [markdown]
# ## Import GDP Data

# %%
gdp = pd.read_csv("./data/total_gdp_ppp_inflation_adjusted.csv", index_col=0)

# %%
gdp = gdp.loc[["Norway", "Saudi Arabia"], "1970":"2005"]

# %%
gdp
